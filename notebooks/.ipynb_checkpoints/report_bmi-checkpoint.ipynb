# %% [markdown]
# # Measuring BMI in OpenSAFELY-TPP
# This short report describes how BMI can be identified in the OpenSAFELY-TPP database, and the strengths and weaknesses of the methods. This is a living document that will be updated to reflect changes to the OpenSAFELY-TPP database and the patient records within.
#
# ## OpenSAFELY
# OpenSAFELY is an analytics platform for conducting analyses on Electronic Health Records inside the secure environment where the records are held. This has multiple benefits:
#
# * We don't transport large volumes of potentially disclosive pseudonymised patient data outside of the secure environments for analysis
# * Analyses can run in near real-time as records are ready for analysis as soon as they appear in the secure environment
# * All infrastructure and analysis code is stored in GitHub repositories, which are open for security review, scientific review, and re-use
#
# A key feature of OpenSAFELY is the use of study definitions, which are formal specifications of the datasets to be generated from the OpenSAFELY database. This takes care of much of the complex EHR data wrangling required to create a dataset in an analysis-ready format. It also creates a library of standardised and validated variable definitions that can be deployed consistently across multiple projects.
#
# The purpose of this report is to describe all such variables that relate to BMI, their relative strengths and weaknesses, in what scenarios they are best deployed. It will also describe potential future definitions that have not yet been implemented.
#
# ## Available Records
# OpenSAFELY-TPP runs inside TPP’s data centre which contains the primary care records for all patients registered at practices using TPP’s SystmOne Clinical Information System. This data centre also imports external datasets from other sources, including A&E attendances and hospital admissions from NHS Digital’s Secondary Use Service, and death registrations from the ONS. More information on available data sources can be found within the OpenSAFELY documentation.

# %%
from IPython.display import display, Markdown
from lib import *

pd.set_option('display.max_rows', 500)
pd.options.mode.chained_assignment = None

# %%
### CONFIGURE OPTIONS HERE ###

# Import file
input_path = '../output/data/input_processed.feather'

# Definitions
definitions = ['derived_bmi', 'computed_bmi', 'recorded_bmi']

# Code dictionary
code_dict = {
    'ethnicity': {1:'White', 2:'Mixed', 3:'Asian', 4:'Black', 5:'Other', np.nan: 'Unknown', 0: 'Unknown'},
    'imd': {0: 'Unknown', 1: '1 Most deprived', 2: '2', 3: '3', 4: '4', 5: '5 Least deprived'}
}

# Other variables to include
other_vars = ['height','weight']

# Dates
dates = True
date_min = '2015-03-01'
date_max = '2022-03-01'
time_delta = 'M'

# Min/max range
min_range = 4
max_range = 200

# Null value – could be multiple values in a list [0,'0',NA]
null = [0]

# Covariates
demographic_covariates = ['age_band', 'sex', 'ethnicity', 'region', 'imd']
clinical_covariates = ['dementia', 'diabetes', 'hypertension', 'learning_disability']

# %%
df_clean = import_clean(input_path, definitions, other_vars, demographic_covariates, 
                        clinical_covariates, null, date_min, date_max, 
                        time_delta, code_dict, dates)

# %% [markdown]
# ## Methods
#
# We define three variable phenotypes: computed, recorded, and derived BMI.
# * Computed BMI refers to BMI calculated from height and weight measurements.
# * Recorded BMI refers to coded events of BMI.
# * Derived BMI refers to the canonical definition used in the OpenSAFELY backend using the `most_recent_bmi()` function, which returns patients' most recent BMI (in the defined period) either computed from weight and height measurements or, where they are not availble, from recorded BMI values.
#
# To evaluate how well each of these phenotypes are populated, we count the number of patients with each phenotype, number of patients missing each phenotype, and number of patients with multiple phenotypes. We also examine the plausibility of each phenotype by looking at the distribution of measurements and counting values out of the expected range. To evaluate how frequently the BMI phenotypes are recorded, we track the number of new measurements recorded over time and compute the average time between updates.
#
# For each of the checks above, we look at the whole population and across each of the following demographic and clinical subgroups to detect any inequalities.
#
# Demographic covariates:
# * Age band
# * Sex
# * Ethnicity
# * Region
# * IMD
#
# Clinical covariates:
# * Dementia
# * Diabetes
# * Hypertension
# * Learning disability

# %% [markdown]
# ## Results

# %% [markdown]
# ### Count of Patients

# %%
patient_counts(df_clean, definitions, demographic_covariates, clinical_covariates)
# Out:
#                                                 derived_bmi   computed_bmi  \
# group               subgroup
# population          N                                1000.0         1000.0
#                     with records              995.0 (100.0)  970.0 (100.0)
# age_band            0-19                       125.0 (12.6)   120.0 (12.4)
#                     20-29                      130.0 (13.1)   130.0 (13.4)
#                     30-39                      125.0 (12.6)   120.0 (12.4)
#                     40-49                      125.0 (12.6)   120.0 (12.4)
#                     50-59                      120.0 (12.1)   110.0 (11.3)
#                     60-69                      125.0 (12.6)   125.0 (12.9)
#                     70-79                      110.0 (11.1)   105.0 (10.8)
#                     80+                        140.0 (14.1)   135.0 (13.9)
# sex                 F                          480.0 (48.2)   465.0 (47.9)
#                     M                          515.0 (51.8)   505.0 (52.1)
# ethnicity           Asian                      145.0 (14.6)   140.0 (14.4)
#                     Black                        70.0 (7.0)     70.0 (7.2)
#                     Mixed                      235.0 (23.6)   230.0 (23.7)
#                     Other                        40.0 (4.0)     35.0 (3.6)
#                     White                      510.0 (51.3)   490.0 (50.5)
# region              East Midlands                65.0 (6.5)     60.0 (6.2)
#                     East of England              65.0 (6.5)     60.0 (6.2)
#                     London                     125.0 (12.6)   120.0 (12.4)
#                     North East                   65.0 (6.5)     65.0 (6.7)
#                     North West                   80.0 (8.0)     75.0 (7.7)
#                     South East                 110.0 (11.1)   105.0 (10.8)
#                     West Midlands                70.0 (7.0)     70.0 (7.2)
#                     Yorkshire and the Humber     70.0 (7.0)     70.0 (7.2)
# imd                 1 Most deprived            195.0 (19.6)   190.0 (19.6)
#                     2                          215.0 (21.6)   210.0 (21.6)
#                     3                          215.0 (21.6)   210.0 (21.6)
#                     4                          190.0 (19.1)   180.0 (18.6)
#                     5 Least deprived           175.0 (17.6)   165.0 (17.0)
#                     Unknown                      10.0 (1.0)     10.0 (1.0)
# dementia            False                      985.0 (99.0)   960.0 (99.0)
#                     True                         10.0 (1.0)     10.0 (1.0)
# diabetes            False                      985.0 (99.0)   960.0 (99.0)
#                     True                         10.0 (1.0)     10.0 (1.0)
# hypertension        False                      985.0 (99.0)   960.0 (99.0)
#                     True                         10.0 (1.0)     10.0 (1.0)
# learning_disability False                      985.0 (99.0)   960.0 (99.0)
#                     True                         10.0 (1.0)     10.0 (1.0)
#
#                                                 recorded_bmi     all_filled
# group               subgroup
# population          N                                 1000.0         1000.0
#                     with records              1000.0 (100.0)  965.0 (100.0)
# age_band            0-19                        125.0 (12.5)   120.0 (12.4)
#                     20-29                       135.0 (13.5)   130.0 (13.5)
#                     30-39                       125.0 (12.5)   120.0 (12.4)
#                     40-49                       125.0 (12.5)   120.0 (12.4)
#                     50-59                       120.0 (12.0)   110.0 (11.4)
#                     60-69                       125.0 (12.5)   125.0 (13.0)
#                     70-79                       110.0 (11.0)   105.0 (10.9)
#                     80+                         140.0 (14.0)   135.0 (14.0)
# sex                 F                           485.0 (48.5)   465.0 (48.2)
#                     M                           515.0 (51.5)   500.0 (51.8)
# ethnicity           Asian                       145.0 (14.5)   140.0 (14.5)
#                     Black                         70.0 (7.0)     70.0 (7.3)
#                     Mixed                       235.0 (23.5)   230.0 (23.8)
#                     Other                         40.0 (4.0)     35.0 (3.6)
#                     White                       510.0 (51.0)   490.0 (50.8)
# region              East Midlands                 65.0 (6.5)     60.0 (6.2)
#                     East of England               65.0 (6.5)     60.0 (6.2)
#                     London                      125.0 (12.5)   120.0 (12.4)
#                     North East                    65.0 (6.5)     65.0 (6.7)
#                     North West                    80.0 (8.0)     75.0 (7.8)
#                     South East                  110.0 (11.0)   105.0 (10.9)
#                     West Midlands                 70.0 (7.0)     70.0 (7.3)
#                     Yorkshire and the Humber      70.0 (7.0)     70.0 (7.3)
# imd                 1 Most deprived             195.0 (19.5)   190.0 (19.7)
#                     2                           215.0 (21.5)   210.0 (21.8)
#                     3                           215.0 (21.5)   210.0 (21.8)
#                     4                           190.0 (19.0)   180.0 (18.7)
#                     5 Least deprived            175.0 (17.5)   165.0 (17.1)
#                     Unknown                       10.0 (1.0)     10.0 (1.0)
# dementia            False                       990.0 (99.0)   955.0 (99.0)
#                     True                          10.0 (1.0)     10.0 (1.0)
# diabetes            False                       990.0 (99.0)   955.0 (99.0)
#                     True                          10.0 (1.0)     10.0 (1.0)
# hypertension        False                       990.0 (99.0)   955.0 (99.0)
#                     True                          10.0 (1.0)     10.0 (1.0)
# learning_disability False                       990.0 (99.0)   955.0 (99.0)
#                     True                          10.0 (1.0)     10.0 (1.0)

# %% [markdown]
# ### Count of Missings

# %%
patient_counts(df_clean, definitions, demographic_covariates, clinical_covariates, missing=True)
# Out:
#                                              derived_bmi  computed_bmi  \
# group               subgroup
# population          N                             1000.0        1000.0
#                     missing records                - (-)  30.0 (100.0)
# age_band            0-19                           - (-)         - (-)
#                     20-29                          - (-)         - (-)
#                     30-39                          - (-)         - (-)
#                     40-49                          - (-)         - (-)
#                     50-59                          - (-)    5.0 (16.7)
#                     60-69                          - (-)         - (-)
#                     70-79                          - (-)         - (-)
#                     80+                            - (-)         - (-)
# sex                 F                              - (-)   20.0 (66.7)
#                     M                              - (-)   15.0 (50.0)
# ethnicity           Asian                          - (-)         - (-)
#                     Black                          - (-)         - (-)
#                     Mixed                          - (-)    5.0 (16.7)
#                     Other                          - (-)         - (-)
#                     White                          - (-)   20.0 (66.7)
# region              East Midlands                  - (-)         - (-)
#                     East of England                - (-)         - (-)
#                     London                         - (-)         - (-)
#                     North East                     - (-)         - (-)
#                     North West                     - (-)         - (-)
#                     South East                     - (-)         - (-)
#                     West Midlands                  - (-)         - (-)
#                     Yorkshire and the Humber       - (-)         - (-)
# imd                 1 Most deprived                - (-)         - (-)
#                     2                              - (-)         - (-)
#                     3                              - (-)    5.0 (16.7)
#                     4                              - (-)   10.0 (33.3)
#                     5 Least deprived               - (-)    5.0 (16.7)
#                     Unknown                        - (-)         - (-)
# dementia            False                          - (-)  30.0 (100.0)
#                     True                           - (-)         - (-)
# diabetes            False                          - (-)  30.0 (100.0)
#                     True                           - (-)         - (-)
# hypertension        False                          - (-)  30.0 (100.0)
#                     True                           - (-)         - (-)
# learning_disability False                          - (-)  30.0 (100.0)
#                     True                           - (-)         - (-)
#
#                                              recorded_bmi all_missing
# group               subgroup
# population          N                              1000.0      1000.0
#                     missing records                 - (-)       - (-)
# age_band            0-19                            - (-)       - (-)
#                     20-29                           - (-)       - (-)
#                     30-39                           - (-)       - (-)
#                     40-49                           - (-)       - (-)
#                     50-59                           - (-)       - (-)
#                     60-69                           - (-)       - (-)
#                     70-79                           - (-)       - (-)
#                     80+                             - (-)       - (-)
# sex                 F                               - (-)       - (-)
#                     M                               - (-)       - (-)
# ethnicity           Asian                           - (-)       - (-)
#                     Black                           - (-)       - (-)
#                     Mixed                           - (-)       - (-)
#                     Other                           - (-)       - (-)
#                     White                           - (-)       - (-)
# region              East Midlands                   - (-)       - (-)
#                     East of England                 - (-)       - (-)
#                     London                          - (-)       - (-)
#                     North East                      - (-)       - (-)
#                     North West                      - (-)       - (-)
#                     South East                      - (-)       - (-)
#                     West Midlands                   - (-)       - (-)
#                     Yorkshire and the Humber        - (-)       - (-)
# imd                 1 Most deprived                 - (-)       - (-)
#                     2                               - (-)       - (-)
#                     3                               - (-)       - (-)
#                     4                               - (-)       - (-)
#                     5 Least deprived                - (-)       - (-)
#                     Unknown                         - (-)       - (-)
# dementia            False                           - (-)       - (-)
#                     True                            - (-)       - (-)
# diabetes            False                           - (-)       - (-)
#                     True                            - (-)       - (-)
# hypertension        False                           - (-)       - (-)
#                     True                            - (-)       - (-)
# learning_disability False                           - (-)       - (-)
#                     True                            - (-)       - (-)

# %% [markdown]
# ### Overlapping Definitions

# %%
display_heatmap(df_clean, definitions)

# %% [markdown]
# ### Distribution of Values

# %% [markdown]
# #### Height and Weight – Inputs for Computed BMI

# %%
fig, ax = plt.subplots(figsize=(12, 8))
plt.hist(df_clean['weight'])
plt.title('Distribution of weight (kg)')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 8))
plt.hist(df_clean['height'])
plt.title('Distribution of height (m)')
plt.show()

# %% [markdown]
# #### Comparison of Distributions

# %%
report_distribution(df_clean, definitions, len(definitions), group='')
for group in demographic_covariates + clinical_covariates:
    report_distribution(df_clean, definitions, len(definitions), group)
# Out:
# Averages:
#                    mean  count
# derived_bmi   27.844921   4575
# computed_bmi  25.760556   2985
# recorded_bmi  21.959392   6850
# Averages by age_band:
#          avg_derived_bmi avg_computed_bmi avg_recorded_bmi ct_derived_bmi  \
# age_band
# 0-19            27.79255        25.838907        21.977565            540
# 20-29          27.162073        25.622424        21.621698            595
# 30-39          27.470145        25.631275        22.062344            565
# 40-49          27.838517        25.508475        21.996956            575
# 50-59          28.360755        25.749585        21.777414            535
# 60-69          28.267725        25.839193         22.12503            630
# 70-79          27.870683        25.724768        22.129886            490
# 80+            27.994049        26.108908        22.000645            640
#
#          ct_computed_bmi ct_recorded_bmi
# age_band
# 0-19                 365             845
# 20-29                405             890
# 30-39                350             860
# 40-49                365             865
# 50-59                335             815
# 60-69                420             890
# 70-79                325             750
# 80+                  425             935
# Averages by sex:
#      avg_derived_bmi  avg_computed_bmi  avg_recorded_bmi  ct_derived_bmi  \
# sex
# F          27.783169         25.718227         21.990612            2235
# M          27.903902         25.799693         21.929917            2340
#
#      ct_computed_bmi  ct_recorded_bmi
# sex
# F               1435             3325
# M               1550             3525
# Averages by ethnicity:
#           avg_derived_bmi avg_computed_bmi avg_recorded_bmi ct_derived_bmi  \
# ethnicity
# Asian            28.03425        25.648854         22.00135            690
# Black           27.062758        25.806499        21.814012            305
# Mixed           27.759203        25.556377         21.95463           1055
# Other           27.229857        25.469767        21.975179            185
# White           27.978494         25.90219        21.970241           2340
#
#           ct_computed_bmi ct_recorded_bmi
# ethnicity
# Asian                 445             955
# Black                 225             515
# Mixed                 720            1605
# Other                  90             260
# White                1505            3515
# Averages by region:
#                          avg_derived_bmi avg_computed_bmi avg_recorded_bmi  \
# region
# East Midlands                  28.347028        25.859576        21.736936
# East of England                28.828861        26.228079        22.271327
# London                         27.639245        25.995349        21.982117
# North East                     27.924048        25.407451        22.147984
# North West                     27.341754        25.066517        22.094313
# South East                     28.067489        25.517189        21.922001
# West Midlands                  27.325166        25.687393        22.298052
# Yorkshire and the Humber       28.150455        25.932239        21.892173
#
#                          ct_derived_bmi ct_computed_bmi ct_recorded_bmi
# region
# East Midlands                       285             185             445
# East of England                     290             210             420
# London                              560             360             845
# North East                          295             200             460
# North West                          385             245             550
# South East                          495             335             745
# West Midlands                       325             205             470
# Yorkshire and the Humber            330             225             480
# Averages by imd:
#                  avg_derived_bmi avg_computed_bmi avg_recorded_bmi  \
# imd
# 1 Most deprived        28.088819        25.766953        22.021699
# 2                      27.815814        25.799589        21.934232
# 3                      27.729451        25.810836        22.019437
# 4                      27.343082        25.761945        21.996113
# 5 Least deprived       28.360605        25.641367        21.800812
# Unknown                26.716323        25.690135        22.031619
#
#                  ct_derived_bmi ct_computed_bmi ct_recorded_bmi
# imd
# 1 Most deprived             865             600            1340
# 2                           995             640            1480
# 3                          1000             665            1475
# 4                           855             535            1300
# 5 Least deprived            810             505            1185
# Unknown                      50              40              75
# Averages by dementia:
#           avg_derived_bmi  avg_computed_bmi  avg_recorded_bmi  ct_derived_bmi  \
# dementia
# False           27.831839         25.774482         21.959531            4530
# True            29.105257         24.341158         21.944582              45
#
#           ct_computed_bmi  ct_recorded_bmi
# dementia
# False                2955             6785
# True                   30               65
# Averages by diabetes:
#           avg_derived_bmi  avg_computed_bmi  avg_recorded_bmi  ct_derived_bmi  \
# diabetes
# False           27.839633          25.75957         21.963613            4540
# True            28.511604          25.86473         21.572919              35
#
#           ct_computed_bmi  ct_recorded_bmi
# diabetes
# False                2955             6775
# True                   30               75
# Averages by hypertension:
#               avg_derived_bmi  avg_computed_bmi  avg_recorded_bmi  \
# hypertension
# False               27.833371         25.767056         21.957901
# True                28.934245         25.098059         22.103763
#
#               ct_derived_bmi  ct_computed_bmi  ct_recorded_bmi
# hypertension
# False                   4525             2955             6780
# True                      50               30               70
# Averages by learning_disability:
#                      avg_derived_bmi  avg_computed_bmi  avg_recorded_bmi  \
# learning_disability
# False                      27.835976         25.757109         21.955430
# True                       28.745415         26.204472         22.348624
#
#                      ct_derived_bmi  ct_computed_bmi  ct_recorded_bmi
# learning_disability
# False                          4530             2960             6780
# True                             45               25               70

# %% [markdown]
# #### Out-of-Range Values

# %%
report_out_of_range(df_clean, definitions, min_range, max_range, len(definitions), null, group='')
# Out:
#        oor_derived_bmi oor_computed_bmi oor_recorded_bmi
# count         5.000000                -                -
# mean          2.803535                -                -
# pct25         2.255777                -                -
# pct75         3.539851                -                -

# %%
for group in demographic_covariates + clinical_covariates:
    report_out_of_range(df_clean, definitions, min_range, max_range, len(definitions), null, group)
# Out:
#          count_derived_bmi mean_derived_bmi pct25_derived_bmi  \
# age_band
# 0-19                     -                -                 -
# 20-29                    -                -                 -
# 30-39                    -                -                 -
# 40-49                    -                -                 -
# 50-59                    -                -                 -
# 60-69                    -                -                 -
# 70-79                    -                -                 -
# 80+                      -                -                 -
#
#          pct75_derived_bmi count_computed_bmi mean_computed_bmi  \
# age_band
# 0-19                     -                  -                 -
# 20-29                    -                  -                 -
# 30-39                    -                  -                 -
# 40-49                    -                  -                 -
# 50-59                    -                  -                 -
# 60-69                    -                  -                 -
# 70-79                    -                  -                 -
# 80+                      -                  -                 -
#
#          pct25_computed_bmi pct75_computed_bmi count_recorded_bmi  \
# age_band
# 0-19                      -                  -                  -
# 20-29                     -                  -                  -
# 30-39                     -                  -                  -
# 40-49                     -                  -                  -
# 50-59                     -                  -                  -
# 60-69                     -                  -                  -
# 70-79                     -                  -                  -
# 80+                       -                  -                  -
#
#          mean_recorded_bmi pct25_recorded_bmi pct75_recorded_bmi
# age_band
# 0-19                     -                  -                  -
# 20-29                    -                  -                  -
# 30-39                    -                  -                  -
# 40-49                    -                  -                  -
# 50-59                    -                  -                  -
# 60-69                    -                  -                  -
# 70-79                    -                  -                  -
# 80+                      -                  -                  -
# Plot redacted due to low counts.
#     count_derived_bmi mean_derived_bmi pct25_derived_bmi pct75_derived_bmi  \
# sex
# F                   -                -                 -                 -
# M                   -                -                 -                 -
#
#     count_computed_bmi mean_computed_bmi pct25_computed_bmi  \
# sex
# F                    -                 -                  -
# M                    -                 -                  -
#
#     pct75_computed_bmi count_recorded_bmi mean_recorded_bmi  \
# sex
# F                    -                  -                 -
# M                    -                  -                 -
#
#     pct25_recorded_bmi pct75_recorded_bmi
# sex
# F                    -                  -
# M                    -                  -
# Plot redacted due to low counts.
#           count_derived_bmi mean_derived_bmi pct25_derived_bmi  \
# ethnicity
# Asian                     -                -                 -
# Black                     -                -                 -
# Mixed                     -                -                 -
# Other                     -                -                 -
# White                     -                -                 -
#
#           pct75_derived_bmi count_computed_bmi mean_computed_bmi  \
# ethnicity
# Asian                     -                  -                 -
# Black                     -                  -                 -
# Mixed                     -                  -                 -
# Other                     -                  -                 -
# White                     -                  -                 -
#
#           pct25_computed_bmi pct75_computed_bmi count_recorded_bmi  \
# ethnicity
# Asian                      -                  -                  -
# Black                      -                  -                  -
# Mixed                      -                  -                  -
# Other                      -                  -                  -
# White                      -                  -                  -
#
#           mean_recorded_bmi pct25_recorded_bmi pct75_recorded_bmi
# ethnicity
# Asian                     -                  -                  -
# Black                     -                  -                  -
# Mixed                     -                  -                  -
# Other                     -                  -                  -
# White                     -                  -                  -
# Plot redacted due to low counts.
#                          count_derived_bmi mean_derived_bmi pct25_derived_bmi  \
# region
# East Midlands                            -                -                 -
# East of England                          -                -                 -
# London                                   -                -                 -
# North East                               -                -                 -
# North West                               -                -                 -
# South East                               -                -                 -
# West Midlands                            -                -                 -
# Yorkshire and the Humber                 -                -                 -
#
#                          pct75_derived_bmi count_computed_bmi  \
# region
# East Midlands                            -                  -
# East of England                          -                  -
# London                                   -                  -
# North East                               -                  -
# North West                               -                  -
# South East                               -                  -
# West Midlands                            -                  -
# Yorkshire and the Humber                 -                  -
#
#                          mean_computed_bmi pct25_computed_bmi  \
# region
# East Midlands                            -                  -
# East of England                          -                  -
# London                                   -                  -
# North East                               -                  -
# North West                               -                  -
# South East                               -                  -
# West Midlands                            -                  -
# Yorkshire and the Humber                 -                  -
#
#                          pct75_computed_bmi count_recorded_bmi  \
# region
# East Midlands                             -                  -
# East of England                           -                  -
# London                                    -                  -
# North East                                -                  -
# North West                                -                  -
# South East                                -                  -
# West Midlands                             -                  -
# Yorkshire and the Humber                  -                  -
#
#                          mean_recorded_bmi pct25_recorded_bmi  \
# region
# East Midlands                            -                  -
# East of England                          -                  -
# London                                   -                  -
# North East                               -                  -
# North West                               -                  -
# South East                               -                  -
# West Midlands                            -                  -
# Yorkshire and the Humber                 -                  -
#
#                          pct75_recorded_bmi
# region
# East Midlands                             -
# East of England                           -
# London                                    -
# North East                                -
# North West                                -
# South East                                -
# West Midlands                             -
# Yorkshire and the Humber                  -
# Plot redacted due to low counts.
#                  count_derived_bmi mean_derived_bmi pct25_derived_bmi  \
# imd
# 1 Most deprived                  -                -                 -
# 2                                -                -                 -
# 3                                -                -                 -
# 4                                -                -                 -
# 5 Least deprived                 -                -                 -
# Unknown                          -                -                 -
#
#                  pct75_derived_bmi count_computed_bmi mean_computed_bmi  \
# imd
# 1 Most deprived                  -                  -                 -
# 2                                -                  -                 -
# 3                                -                  -                 -
# 4                                -                  -                 -
# 5 Least deprived                 -                  -                 -
# Unknown                          -                  -                 -
#
#                  pct25_computed_bmi pct75_computed_bmi count_recorded_bmi  \
# imd
# 1 Most deprived                   -                  -                  -
# 2                                 -                  -                  -
# 3                                 -                  -                  -
# 4                                 -                  -                  -
# 5 Least deprived                  -                  -                  -
# Unknown                           -                  -                  -
#
#                  mean_recorded_bmi pct25_recorded_bmi pct75_recorded_bmi
# imd
# 1 Most deprived                  -                  -                  -
# 2                                -                  -                  -
# 3                                -                  -                  -
# 4                                -                  -                  -
# 5 Least deprived                 -                  -                  -
# Unknown                          -                  -                  -
# Plot redacted due to low counts.
#          count_derived_bmi mean_derived_bmi pct25_derived_bmi  \
# dementia
# False                    -                -                 -
# True                     -                -                 -
#
#          pct75_derived_bmi count_computed_bmi mean_computed_bmi  \
# dementia
# False                    -                  -                 -
# True                     -                  -                 -
#
#          pct25_computed_bmi pct75_computed_bmi count_recorded_bmi  \
# dementia
# False                     -                  -                  -
# True                      -                  -                  -
#
#          mean_recorded_bmi pct25_recorded_bmi pct75_recorded_bmi
# dementia
# False                    -                  -                  -
# True                     -                  -                  -
# Plot redacted due to low counts.
#          count_derived_bmi mean_derived_bmi pct25_derived_bmi  \
# diabetes
# False                    -                -                 -
# True                     -                -                 -
#
#          pct75_derived_bmi count_computed_bmi mean_computed_bmi  \
# diabetes
# False                    -                  -                 -
# True                     -                  -                 -
#
#          pct25_computed_bmi pct75_computed_bmi count_recorded_bmi  \
# diabetes
# False                     -                  -                  -
# True                      -                  -                  -
#
#          mean_recorded_bmi pct25_recorded_bmi pct75_recorded_bmi
# diabetes
# False                    -                  -                  -
# True                     -                  -                  -
# Plot redacted due to low counts.
#              count_derived_bmi mean_derived_bmi pct25_derived_bmi  \
# hypertension
# False                        -                -                 -
# True                         -                -                 -
#
#              pct75_derived_bmi count_computed_bmi mean_computed_bmi  \
# hypertension
# False                        -                  -                 -
# True                         -                  -                 -
#
#              pct25_computed_bmi pct75_computed_bmi count_recorded_bmi  \
# hypertension
# False                         -                  -                  -
# True                          -                  -                  -
#
#              mean_recorded_bmi pct25_recorded_bmi pct75_recorded_bmi
# hypertension
# False                        -                  -                  -
# True                         -                  -                  -
# Plot redacted due to low counts.
#                     count_derived_bmi mean_derived_bmi pct25_derived_bmi  \
# learning_disability
# False                               -                -                 -
# True                                -                -                 -
#
#                     pct75_derived_bmi count_computed_bmi mean_computed_bmi  \
# learning_disability
# False                               -                  -                 -
# True                                -                  -                 -
#
#                     pct25_computed_bmi pct75_computed_bmi count_recorded_bmi  \
# learning_disability
# False                                -                  -                  -
# True                                 -                  -                  -
#
#                     mean_recorded_bmi pct25_recorded_bmi pct75_recorded_bmi
# learning_disability
# False                               -                  -                  -
# True                                -                  -                  -
# Plot redacted due to low counts.

# %% [markdown]
# ### New Records Over Time

# %%
records_over_time(df_clean, definitions, demographic_covariates, clinical_covariates)

# %% [markdown]
# ### Average Time Between Updates

# %%
report_update_frequency(df_clean, definitions, time_delta, len(definitions), group='')
# Out:
# Average update frequency by M:
#                          avg_diff  count
# date_diff_derived_bmi   14.273617   3580
# date_diff_computed_bmi  17.955379   2015
# date_diff_recorded_bmi  10.430672   5850

# %%
for group in demographic_covariates + clinical_covariates:
    report_update_frequency(df_clean, definitions, time_delta, len(definitions), group)
# Out:
# Average update frequencies by M:
#          avg_date_diff_derived_bmi avg_date_diff_computed_bmi  \
# age_band
# 0-19                     14.645783                   16.04065
# 20-29                    14.015054                  18.492754
# 30-39                    13.735892                  17.829694
# 40-49                    14.636971                  18.065306
# 50-59                    14.768496                  19.340807
# 60-69                    13.922465                  18.187713
# 70-79                    13.627604                  17.908257
# 80+                          14.79                  17.808362
#
#          avg_date_diff_recorded_bmi ct_date_diff_derived_bmi  \
# age_band
# 0-19                      10.326389                      415
# 20-29                     10.943347                      465
# 30-39                     10.168707                      445
# 40-49                     10.214865                      450
# 50-59                     10.123033                      420
# 60-69                     10.312336                      505
# 70-79                     10.633956                      385
# 80+                       10.699495                      500
#
#          ct_date_diff_computed_bmi ct_date_diff_recorded_bmi
# age_band
# 0-19                           245                       720
# 20-29                          275                       760
# 30-39                          230                       735
# 40-49                          245                       740
# 50-59                          225                       700
# 60-69                          295                       760
# 70-79                          220                       640
# 80+                            285                       790
# Average update frequencies by M:
#      avg_date_diff_derived_bmi  avg_date_diff_computed_bmi  \
# sex
# F                    14.046207                   17.740206
# M                    14.492055                   18.154728
#
#      avg_date_diff_recorded_bmi  ct_date_diff_derived_bmi  \
# sex
# F                     10.259233                      1755
# M                     10.592814                      1825
#
#      ct_date_diff_computed_bmi  ct_date_diff_recorded_bmi
# sex
# F                          970                       2845
# M                         1045                       3005
# Average update frequencies by M:
#           avg_date_diff_derived_bmi avg_date_diff_computed_bmi  \
# ethnicity
# Asian                     13.775137                  17.727575
# Black                     14.898305                  17.612903
# Mixed                     14.962056                  17.894094
# Other                     14.527027                  19.428571
# White                     14.014208                  18.023669
#
#           avg_date_diff_recorded_bmi ct_date_diff_derived_bmi  \
# ethnicity
# Asian                      10.963009                      545
# Black                        9.63964                      235
# Mixed                      10.445906                      815
# Other                      10.552036                      150
# White                       10.38802                     1830
#
#           ct_date_diff_computed_bmi ct_date_diff_recorded_bmi
# ethnicity
# Asian                           300                       810
# Black                           155                       445
# Mixed                           490                      1370
# Other                            55                       220
# White                          1015                      3005
# Average update frequencies by M:
#                          avg_date_diff_derived_bmi avg_date_diff_computed_bmi  \
# region
# East Midlands                            14.764706                      18.08
# East of England                          13.872247                  17.691781
# London                                   13.816092                  19.084034
# North East                               15.263158                  15.529412
# North West                               13.535714                  17.164706
# South East                               15.401575                  17.179039
# West Midlands                            13.775591                  16.050725
# Yorkshire and the Humber                 13.301158                  19.715232
#
#                          avg_date_diff_recorded_bmi ct_date_diff_derived_bmi  \
# region
# East Midlands                             10.530184                      220
# East of England                           10.052925                      225
# London                                    10.543056                      435
# North East                                10.266497                      230
# North West                                10.335443                      310
# South East                                10.373418                      380
# West Midlands                             10.594527                      255
# Yorkshire and the Humber                  11.017073                      260
#
#                          ct_date_diff_computed_bmi ct_date_diff_recorded_bmi
# region
# East Midlands                                  125                       380
# East of England                                145                       360
# London                                         240                       720
# North East                                     135                       395
# North West                                     170                       475
# South East                                     230                       630
# West Midlands                                  140                       400
# Yorkshire and the Humber                       150                       410
# Average update frequencies by M:
#                  avg_date_diff_derived_bmi avg_date_diff_computed_bmi  \
# imd
# 1 Most deprived                  14.438806                  17.502451
# 2                                14.235897                  18.988399
# 3                                14.340561                  17.748359
# 4                                15.115269                   16.92068
# 5 Least deprived                 13.225705                  18.469027
# Unknown                          13.552632                  18.827586
#
#                  avg_date_diff_recorded_bmi ct_date_diff_derived_bmi  \
# imd
# 1 Most deprived                   10.350831                      670
# 2                                 10.398734                      780
# 3                                  10.37619                      785
# 4                                 10.567568                      670
# 5 Least deprived                   10.40455                      640
# Unknown                           11.655738                       40
#
#                  ct_date_diff_computed_bmi ct_date_diff_recorded_bmi
# imd
# 1 Most deprived                        410                      1145
# 2                                      430                      1265
# 3                                      455                      1260
# 4                                      355                      1110
# 5 Least deprived                       340                      1010
# Unknown                                 30                        60
# Average update frequencies by M:
#           avg_date_diff_derived_bmi  avg_date_diff_computed_bmi  \
# dementia
# False                     14.296526                   17.913413
# True                      12.081081                   22.368421
#
#           avg_date_diff_recorded_bmi  ct_date_diff_derived_bmi  \
# dementia
# False                      10.425367                      3540
# True                       11.000000                        35
#
#           ct_date_diff_computed_bmi  ct_date_diff_recorded_bmi
# dementia
# False                          2000                       5795
# True                             20                         55
# Average update frequencies by M:
#           avg_date_diff_derived_bmi  avg_date_diff_computed_bmi  \
# diabetes
# False                     14.258164                   18.006507
# True                      16.384615                   12.578947
#
#           avg_date_diff_recorded_bmi  ct_date_diff_derived_bmi  \
# diabetes
# False                      10.454970                      3550
# True                        8.234375                        25
#
#           ct_date_diff_computed_bmi  ct_date_diff_recorded_bmi
# diabetes
# False                          2000                       5785
# True                             20                         65
# Average update frequencies by M:
#               avg_date_diff_derived_bmi  avg_date_diff_computed_bmi  \
# hypertension
# False                         14.289266                   17.902402
# True                          12.815789                   23.526316
#
#               avg_date_diff_recorded_bmi  ct_date_diff_derived_bmi  \
# hypertension
# False                          10.432199                      3540
# True                           10.283333                        40
#
#               ct_date_diff_computed_bmi  ct_date_diff_recorded_bmi
# hypertension
# False                              2000                       5790
# True                                 20                         60
# Average update frequencies by M:
#                      avg_date_diff_derived_bmi  avg_date_diff_computed_bmi  \
# learning_disability
# False                                14.267852                   17.836826
# True                                 14.857143                   36.230769
#
#                      avg_date_diff_recorded_bmi  ct_date_diff_derived_bmi  \
# learning_disability
# False                                 10.427634                      3545
# True                                  10.728814                        35
#
#                      ct_date_diff_computed_bmi  ct_date_diff_recorded_bmi
# learning_disability
# False                                     2005                       5790
# True                                        15                         60
