# %%
import os
import pandas as pd

from IPython.display import display, Markdown, Image

pd.set_option('display.max_rows', 500)
pd.options.mode.chained_assignment = None

# %%
### CONFIGURE ###
definitions = ['weight', 'weight_backend']
covariates = ['_age_band','_sex','_ethnicity','_region','_imd','_dementia','_diabetes','_hypertension','_learning_disability']
output_path = 'phenotype_validation_weight'

# %% [markdown]
# # Weight
# ## Count of Patients

# %%
df_patient_counts = pd.read_csv(f'../output/{output_path}/tables/patient_counts_filled.csv').set_index(['group','subgroup'])
display(df_patient_counts)
# Out:
#                                                       weight  weight_backend  \
# group               subgroup
# all                 with records              1000.0 (100.0)  1000.0 (100.0)
# age_band            0-19                       125.0 (100.0)   125.0 (100.0)
#                     20-29                      145.0 (100.0)   145.0 (100.0)
#                     30-39                      110.0 (100.0)   110.0 (100.0)
#                     40-49                      130.0 (100.0)   130.0 (100.0)
#                     50-59                      120.0 (100.0)   120.0 (100.0)
#                     60-69                      130.0 (100.0)   130.0 (100.0)
#                     70-79                      130.0 (100.0)   130.0 (100.0)
#                     80+                        110.0 (100.0)   110.0 (100.0)
# sex                 F                          505.0 (100.0)   505.0 (100.0)
#                     M                          495.0 (100.0)   495.0 (100.0)
# ethnicity           Asian                      135.0 (100.0)   135.0 (100.0)
#                     Black                       75.0 (100.0)    75.0 (100.0)
#                     Mixed                      270.0 (100.0)   270.0 (100.0)
#                     Other                       30.0 (100.0)    30.0 (100.0)
#                     White                      495.0 (100.0)   495.0 (100.0)
# region              East Midlands               70.0 (100.0)    70.0 (100.0)
#                     East of England             65.0 (100.0)    65.0 (100.0)
#                     London                     140.0 (100.0)   140.0 (100.0)
#                     North East                  65.0 (100.0)    65.0 (100.0)
#                     North West                  60.0 (100.0)    60.0 (100.0)
#                     South East                 115.0 (100.0)   115.0 (100.0)
#                     West Midlands               60.0 (100.0)    60.0 (100.0)
#                     Yorkshire and the Humber    75.0 (100.0)    75.0 (100.0)
# imd                 1 Most deprived            215.0 (100.0)   215.0 (100.0)
#                     2                          190.0 (100.0)   190.0 (100.0)
#                     3                          215.0 (100.0)   215.0 (100.0)
#                     4                          190.0 (100.0)   190.0 (100.0)
#                     5 Least deprived           185.0 (100.0)   185.0 (100.0)
#                     Unknown                     10.0 (100.0)    10.0 (100.0)
# dementia            False                      990.0 (100.0)   990.0 (100.0)
#                     True                        10.0 (100.0)    10.0 (100.0)
# diabetes            False                      990.0 (100.0)   990.0 (100.0)
#                     True                        10.0 (100.0)    10.0 (100.0)
# hypertension        False                      990.0 (100.0)   990.0 (100.0)
#                     True                        10.0 (100.0)    10.0 (100.0)
# learning_disability False                      990.0 (100.0)   990.0 (100.0)
#                     True                        10.0 (100.0)    10.0 (100.0)
#
#                                                   all_filled  population
# group               subgroup
# all                 with records              1000.0 (100.0)      1000.0
# age_band            0-19                       125.0 (100.0)       125.0
#                     20-29                      145.0 (100.0)       145.0
#                     30-39                      110.0 (100.0)       110.0
#                     40-49                      130.0 (100.0)       130.0
#                     50-59                      120.0 (100.0)       120.0
#                     60-69                      130.0 (100.0)       130.0
#                     70-79                      130.0 (100.0)       130.0
#                     80+                        110.0 (100.0)       110.0
# sex                 F                          505.0 (100.0)       505.0
#                     M                          495.0 (100.0)       495.0
# ethnicity           Asian                      135.0 (100.0)       135.0
#                     Black                       75.0 (100.0)        75.0
#                     Mixed                      270.0 (100.0)       270.0
#                     Other                       30.0 (100.0)        30.0
#                     White                      495.0 (100.0)       495.0
# region              East Midlands               70.0 (100.0)        70.0
#                     East of England             65.0 (100.0)        65.0
#                     London                     140.0 (100.0)       140.0
#                     North East                  65.0 (100.0)        65.0
#                     North West                  60.0 (100.0)        60.0
#                     South East                 115.0 (100.0)       115.0
#                     West Midlands               60.0 (100.0)        60.0
#                     Yorkshire and the Humber    75.0 (100.0)        75.0
# imd                 1 Most deprived            215.0 (100.0)       215.0
#                     2                          190.0 (100.0)       190.0
#                     3                          215.0 (100.0)       215.0
#                     4                          190.0 (100.0)       190.0
#                     5 Least deprived           185.0 (100.0)       185.0
#                     Unknown                     10.0 (100.0)        10.0
# dementia            False                      990.0 (100.0)       990.0
#                     True                        10.0 (100.0)        10.0
# diabetes            False                      990.0 (100.0)       990.0
#                     True                        10.0 (100.0)        10.0
# hypertension        False                      990.0 (100.0)       990.0
#                     True                        10.0 (100.0)        10.0
# learning_disability False                      990.0 (100.0)       990.0
#                     True                        10.0 (100.0)        10.0

# %% [markdown]
# ## Count of Missings

# %%
df_patient_counts_missing = pd.read_csv(f'../output/{output_path}/tables/patient_counts_missing.csv').set_index(['group','subgroup'])
display(df_patient_counts_missing)
# Out:
#                                              weight weight_backend  \
# group               subgroup
# all                 missing records           - (-)          - (-)
# age_band            0-19                      - (-)          - (-)
#                     20-29                     - (-)          - (-)
#                     30-39                     - (-)          - (-)
#                     40-49                     - (-)          - (-)
#                     50-59                     - (-)          - (-)
#                     60-69                     - (-)          - (-)
#                     70-79                     - (-)          - (-)
#                     80+                       - (-)          - (-)
# sex                 F                         - (-)          - (-)
#                     M                         - (-)          - (-)
# ethnicity           Asian                     - (-)          - (-)
#                     Black                     - (-)          - (-)
#                     Mixed                     - (-)          - (-)
#                     Other                     - (-)          - (-)
#                     White                     - (-)          - (-)
# region              East Midlands             - (-)          - (-)
#                     East of England           - (-)          - (-)
#                     London                    - (-)          - (-)
#                     North East                - (-)          - (-)
#                     North West                - (-)          - (-)
#                     South East                - (-)          - (-)
#                     West Midlands             - (-)          - (-)
#                     Yorkshire and the Humber  - (-)          - (-)
# imd                 1 Most deprived           - (-)          - (-)
#                     2                         - (-)          - (-)
#                     3                         - (-)          - (-)
#                     4                         - (-)          - (-)
#                     5 Least deprived          - (-)          - (-)
#                     Unknown                   - (-)          - (-)
# dementia            False                     - (-)          - (-)
#                     True                      - (-)          - (-)
# diabetes            False                     - (-)          - (-)
#                     True                      - (-)          - (-)
# hypertension        False                     - (-)          - (-)
#                     True                      - (-)          - (-)
# learning_disability False                     - (-)          - (-)
#                     True                      - (-)          - (-)
#
#                                              all_missing  population
# group               subgroup
# all                 missing records                - (-)        1000
# age_band            0-19                           - (-)         125
#                     20-29                          - (-)         145
#                     30-39                          - (-)         110
#                     40-49                          - (-)         130
#                     50-59                          - (-)         120
#                     60-69                          - (-)         130
#                     70-79                          - (-)         130
#                     80+                            - (-)         110
# sex                 F                              - (-)         505
#                     M                              - (-)         495
# ethnicity           Asian                          - (-)         135
#                     Black                          - (-)          75
#                     Mixed                          - (-)         270
#                     Other                          - (-)          30
#                     White                          - (-)         495
# region              East Midlands                  - (-)          70
#                     East of England                - (-)          65
#                     London                         - (-)         140
#                     North East                     - (-)          65
#                     North West                     - (-)          60
#                     South East                     - (-)         115
#                     West Midlands                  - (-)          60
#                     Yorkshire and the Humber       - (-)          75
# imd                 1 Most deprived                - (-)         215
#                     2                              - (-)         190
#                     3                              - (-)         215
#                     4                              - (-)         190
#                     5 Least deprived               - (-)         185
#                     Unknown                        - (-)          10
# dementia            False                          - (-)         990
#                     True                           - (-)          10
# diabetes            False                          - (-)         990
#                     True                           - (-)          10
# hypertension        False                          - (-)         990
#                     True                           - (-)          10
# learning_disability False                          - (-)         990
#                     True                           - (-)          10

# %% [markdown]
# ## Distribution of Values
#
# ### Comparison of Distributions

# %%
for suffix in [''] + covariates:    
    df_distribution = pd.read_csv(f'../output/{output_path}/tables/avg_value{suffix}.csv', index_col=0)
    display(df_distribution)
    
    img_exist = os.path.exists(f'../output/{output_path}/figures/distribution{suffix}.png')
    
    if img_exist:
        img_distribution = Image(f'../output/{output_path}/figures/distribution{suffix}.png')
        display(img_distribution)
    else: 
        print('Plot redacted due to low counts.')
# Out:
#                      mean  count
# weight          69.911242   5570
# weight_backend  69.944520   5545
#           avg_weight  avg_weight_backend  ct_weight  ct_weight_backend
# age_band
# 0-19       70.509948           69.943371        705                710
# 20-29      70.111694           70.070888        810                815
# 30-39      68.993233           69.691171        610                620
# 40-49      69.479428           69.981564        720                705
# 50-59      70.156375           70.080769        685                675
# 60-69      70.077610           70.285071        705                690
# 70-79      70.272724           69.525654        715                720
# 80+        69.492941           69.949048        620                615
#      avg_weight  avg_weight_backend  ct_weight  ct_weight_backend
# sex
# F     70.065780           69.971693       2830               2825
# M     69.751858           69.916288       2745               2720
#            avg_weight  avg_weight_backend  ct_weight  ct_weight_backend
# ethnicity
# Asian       69.745766           70.734172        750                745
# Black       70.039338           69.007680        405                410
# Mixed       70.356730           70.019228       1495               1485
# Other       69.035531           70.342251        170                160
# White       69.750277           69.807205       2750               2745
#                           avg_weight  avg_weight_backend  ct_weight  \
# region
# East Midlands              70.782597           70.256322        375
# East of England            69.812061           70.838677        380
# London                     69.815377           70.259629        775
# North East                 70.150924           69.817507        385
# North West                 70.331588           69.339616        340
# South East                 69.881764           69.302950        645
# West Midlands              69.434793           70.570271        320
# Yorkshire and the Humber   69.621553           69.819890        435
#
#                           ct_weight_backend
# region
# East Midlands                           375
# East of England                         390
# London                                  785
# North East                              330
# North West                              335
# South East                              620
# West Midlands                           340
# Yorkshire and the Humber                440
#                   avg_weight  avg_weight_backend  ct_weight  ct_weight_backend
# imd
# 1 Most deprived    69.863431           69.936204       1185               1175
# 2                  69.999594           70.425283       1045               1035
# 3                  70.028015           69.638366       1215               1200
# 4                  69.704823           70.020630       1040               1025
# 5 Least deprived   70.069979           69.700321       1025               1065
# Unknown            67.774363           71.294859         60                 45
#           avg_weight  avg_weight_backend  ct_weight  ct_weight_backend
# dementia
# False      69.892191           69.943617       5525               5490
# True       72.150672           70.029973         45                 60
#           avg_weight  avg_weight_backend  ct_weight  ct_weight_backend
# diabetes
# False      69.899015           69.924171       5520               5495
# True       71.184475           72.137065         55                 50
#               avg_weight  avg_weight_backend  ct_weight  ct_weight_backend
# hypertension
# False          69.883275           69.944326       5515               5490
# True           72.666003           69.964299         55                 55
#                      avg_weight  avg_weight_backend  ct_weight  \
# learning_disability
# False                 69.919723           69.942526       5510
# True                  69.157496           70.133227         60
#
#                      ct_weight_backend
# learning_disability
# False                             5490
# True                                60

# %% [markdown]
# ## Out-of-Range Values

# %%
for suffix in [''] + covariates: 
    df_oor = pd.read_csv(f'../output/{output_path}/tables/out_of_range{suffix}.csv', index_col=0)
    display(df_oor)
    
    img_exist = os.path.exists(f'../output/{output_path}/figures/out_of_range{suffix}.png')
    
    if img_exist:
        img_oor = Image(f'../output/{output_path}/figures/out_of_range{suffix}.png')
        display(img_oor)
    else: 
        print('Plot redacted due to low counts.')
# Out:
#       oor_weight oor_weight_backend
# index
# count          -                  -
# mean           -                  -
# pct25          -                  -
# pct75          -                  -
#          count_weight mean_weight pct25_weight pct75_weight  \
# age_band
# 0-19                -           -            -            -
# 20-29               -           -            -            -
# 30-39               -           -            -            -
# 40-49               -           -            -            -
# 50-59               -           -            -            -
# 60-69               -           -            -            -
# 70-79               -           -            -            -
# 80+                 -           -            -            -
#
#          count_weight_backend mean_weight_backend pct25_weight_backend  \
# age_band
# 0-19                        -                   -                    -
# 20-29                       -                   -                    -
# 30-39                       -                   -                    -
# 40-49                       -                   -                    -
# 50-59                       -                   -                    -
# 60-69                       -                   -                    -
# 70-79                       -                   -                    -
# 80+                         -                   -                    -
#
#          pct75_weight_backend
# age_band
# 0-19                        -
# 20-29                       -
# 30-39                       -
# 40-49                       -
# 50-59                       -
# 60-69                       -
# 70-79                       -
# 80+                         -
# Plot redacted due to low counts.
#     count_weight mean_weight pct25_weight pct75_weight count_weight_backend  \
# sex
# F              -           -            -            -                    -
# M              -           -            -            -                    -
#
#     mean_weight_backend pct25_weight_backend pct75_weight_backend
# sex
# F                     -                    -                    -
# M                     -                    -                    -
# Plot redacted due to low counts.
#           count_weight mean_weight pct25_weight pct75_weight  \
# ethnicity
# Asian                -           -            -            -
# Black                -           -            -            -
# Mixed                -           -            -            -
# Other                -           -            -            -
# White                -           -            -            -
#
#           count_weight_backend mean_weight_backend pct25_weight_backend  \
# ethnicity
# Asian                        -                   -                    -
# Black                        -                   -                    -
# Mixed                        -                   -                    -
# Other                        -                   -                    -
# White                        -                   -                    -
#
#           pct75_weight_backend
# ethnicity
# Asian                        -
# Black                        -
# Mixed                        -
# Other                        -
# White                        -
# Plot redacted due to low counts.
#                          count_weight mean_weight pct25_weight pct75_weight  \
# region
# East Midlands                       -           -            -            -
# East of England                     -           -            -            -
# London                              -           -            -            -
# North East                          -           -            -            -
# North West                          -           -            -            -
# South East                          -           -            -            -
# West Midlands                       -           -            -            -
# Yorkshire and the Humber            -           -            -            -
#
#                          count_weight_backend mean_weight_backend  \
# region
# East Midlands                               -                   -
# East of England                             -                   -
# London                                      -                   -
# North East                                  -                   -
# North West                                  -                   -
# South East                                  -                   -
# West Midlands                               -                   -
# Yorkshire and the Humber                    -                   -
#
#                          pct25_weight_backend pct75_weight_backend
# region
# East Midlands                               -                    -
# East of England                             -                    -
# London                                      -                    -
# North East                                  -                    -
# North West                                  -                    -
# South East                                  -                    -
# West Midlands                               -                    -
# Yorkshire and the Humber                    -                    -
# Plot redacted due to low counts.
#                  count_weight mean_weight pct25_weight pct75_weight  \
# imd
# 1 Most deprived             -           -            -            -
# 2                           -           -            -            -
# 3                           -           -            -            -
# 4                           -           -            -            -
# 5 Least deprived            -           -            -            -
# Unknown                     -           -            -            -
#
#                  count_weight_backend mean_weight_backend  \
# imd
# 1 Most deprived                     -                   -
# 2                                   -                   -
# 3                                   -                   -
# 4                                   -                   -
# 5 Least deprived                    -                   -
# Unknown                             -                   -
#
#                  pct25_weight_backend pct75_weight_backend
# imd
# 1 Most deprived                     -                    -
# 2                                   -                    -
# 3                                   -                    -
# 4                                   -                    -
# 5 Least deprived                    -                    -
# Unknown                             -                    -
# Plot redacted due to low counts.
#          count_weight mean_weight pct25_weight pct75_weight  \
# dementia
# False               -           -            -            -
# True                -           -            -            -
#
#          count_weight_backend mean_weight_backend pct25_weight_backend  \
# dementia
# False                       -                   -                    -
# True                        -                   -                    -
#
#          pct75_weight_backend
# dementia
# False                       -
# True                        -
# Plot redacted due to low counts.
#          count_weight mean_weight pct25_weight pct75_weight  \
# diabetes
# False               -           -            -            -
# True                -           -            -            -
#
#          count_weight_backend mean_weight_backend pct25_weight_backend  \
# diabetes
# False                       -                   -                    -
# True                        -                   -                    -
#
#          pct75_weight_backend
# diabetes
# False                       -
# True                        -
# Plot redacted due to low counts.
#              count_weight mean_weight pct25_weight pct75_weight  \
# hypertension
# False                   -           -            -            -
# True                    -           -            -            -
#
#              count_weight_backend mean_weight_backend pct25_weight_backend  \
# hypertension
# False                           -                   -                    -
# True                            -                   -                    -
#
#              pct75_weight_backend
# hypertension
# False                           -
# True                            -
# Plot redacted due to low counts.
#                     count_weight mean_weight pct25_weight pct75_weight  \
# learning_disability
# False                          -           -            -            -
# True                           -           -            -            -
#
#                     count_weight_backend mean_weight_backend  \
# learning_disability
# False                                  -                   -
# True                                   -                   -
#
#                     pct25_weight_backend pct75_weight_backend
# learning_disability
# False                                  -                    -
# True                                   -                    -
# Plot redacted due to low counts.
